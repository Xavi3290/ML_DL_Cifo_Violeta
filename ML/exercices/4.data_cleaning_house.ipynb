# %% [markdown]
# # **Cleaning**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/house_pricing.csv', sep=',')

# %% [markdown]
# ## How many nulls

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 35 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotArea        1460 non-null   int64
#  3   Street         1460 non-null   object
#  4   Utilities      1460 non-null   object
#  5   LandSlope      1460 non-null   object
#  6   HouseStyle     1460 non-null   object
#  7   YearBuilt      1460 non-null   int64
#  8   YearRemodAdd   1460 non-null   int64
#  9   RoofStyle      1460 non-null   object
#  10  Foundation     1460 non-null   object
#  11  TotalBsmtSF    1460 non-null   int64
#  12  Heating        1460 non-null   object
#  13  CentralAir     1460 non-null   object
#  14  Electrical     1459 non-null   object
#  15  1stFlrSF       1460 non-null   int64
#  16  2ndFlrSF       1460 non-null   int64
# ...

# %%
df.head()
# Out:
#    Id MSZoning  LotArea Street Utilities LandSlope HouseStyle  YearBuilt  \
# 0   1       RL     8450   Pave    AllPub       Gtl     2Story       2003
# 1   2       RL     9600   Pave    AllPub       Gtl     1Story       1976
# 2   3       RL    11250   Pave    AllPub       Gtl     2Story       2001
# 3   4       RL     9550   Pave    AllPub       Gtl     2Story       1915
# 4   5       RL    14260   Pave    AllPub       Gtl     2Story       2000
#
#    YearRemodAdd RoofStyle  ... GarageYrBlt  GarageFinish GarageCars  \
# 0          2003     Gable  ...      2003.0           RFn          2
# 1          1976     Gable  ...      1976.0           RFn          2
# 2          2002     Gable  ...      2001.0           RFn          2
# 3          1970     Gable  ...      1998.0           Unf          3
# 4          2000     Gable  ...      2000.0           RFn          3
#
#   GarageArea PavedDrive  OpenPorchSF  EnclosedPorch  PoolArea  MiscFeature  \
# ...

# %%
df.shape
# Out:
# (1460, 35)

# %% [markdown]
# ## Change nulls

# %% [markdown]
# ### Electical

# %%
df[df["Electrical"].isna()].T
# Out:
#                   1379
# Id                1380
# MSZoning            RL
# LotArea           9735
# Street            Pave
# Utilities       AllPub
# LandSlope          Gtl
# HouseStyle        SLvl
# YearBuilt         2006
# YearRemodAdd      2007
# RoofStyle        Gable
# Foundation       PConc
# TotalBsmtSF        384
# Heating           GasA
# CentralAir           Y
# Electrical         NaN
# 1stFlrSF           754
# 2ndFlrSF           640
# GrLivArea         1394
# BsmtFullBath         0
# FullBath             2
# BedroomAbvGr         3
# KitchenAbvGr         1
# TotRmsAbvGrd         7
# Fireplaces           0
# GarageType     BuiltIn
# GarageYrBlt     2007.0
# GarageFinish       Fin
# GarageCars           2
# GarageArea         400
# PavedDrive           Y
# OpenPorchSF          0
# EnclosedPorch        0
# PoolArea             0
# MiscFeature        NaN
# SalePrice       167500

# %%
df["Electrical"].value_counts()
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %%
df.loc[1379, "Electrical"] = "Sbrkr"   #The only nun change for the most value
df.loc[1379]
# Out:
# Id                  1380
# MSZoning              RL
# LotArea             9735
# Street              Pave
# Utilities         AllPub
# LandSlope            Gtl
# HouseStyle          SLvl
# YearBuilt           2006
# YearRemodAdd        2007
# RoofStyle          Gable
# Foundation         PConc
# TotalBsmtSF          384
# Heating             GasA
# CentralAir             Y
# Electrical         Sbrkr
# 1stFlrSF             754
# 2ndFlrSF             640
# GrLivArea           1394
# BsmtFullBath           0
# FullBath               2
# BedroomAbvGr           3
# KitchenAbvGr           1
# TotRmsAbvGrd           7
# Fireplaces             0
# GarageType       BuiltIn
# GarageYrBlt       2007.0
# GarageFinish         Fin
# GarageCars             2
# GarageArea           400
# PavedDrive             Y
# OpenPorchSF            0
# EnclosedPorch          0
# PoolArea               0
# MiscFeature          NaN
# SalePrice         167500
# Name: 1379, dtype: object

# %% [markdown]
# ### GarageType

# %%
df[df["GarageType"].isna()].T
# Out:
#                  39      48      78       88      89      99      108   \
# Id                 40      49      79       89      90     100     109
# MSZoning           RL      RM      RL  C (all)      RL      RL      RM
# LotArea          6040    4456   10778     8470    8070    9320    8500
# Street           Pave    Pave    Pave     Pave    Pave    Pave    Pave
# Utilities      AllPub  AllPub  AllPub   AllPub  AllPub  AllPub  AllPub
# LandSlope         Gtl     Gtl     Gtl      Gtl     Gtl     Gtl     Gtl
# HouseStyle     1Story  2Story  1Story   1.5Fin  1Story  1Story  1.5Fin
# YearBuilt        1955    1920    1968     1915    1994    1959    1919
# YearRemodAdd     1955    2008    1968     1982    1995    1959    2005
# RoofStyle       Gable   Gable     Hip      Hip   Gable   Gable   Gable
# Foundation      PConc  BrkTil  CBlock   CBlock   PConc  CBlock  CBlock
# TotalBsmtSF         0     736    1768     1013     990     950     793
# ...

# %%
df["GarageType"].value_counts()
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
df.loc[df["GarageType"].isna(), "GarageType"] = 0       #0 ya que no hay 
df["GarageType"].value_counts()
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# 0           81
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %% [markdown]
# ### GarageYrBlt and GarageFinish

# %%
df.loc[df["GarageYrBlt"].isna(), "GarageYrBlt"] = -1    #Le pongo -1 para representar que no hay nada
df.loc[df["GarageFinish"].isna(), "GarageFinish"] = 0   #0 ya que no se a hecho

# %%
df["GarageYrBlt"].value_counts()
df["GarageFinish"].value_counts()
# Out:
# Unf    605
# RFn    422
# Fin    352
# 0       81
# Name: GarageFinish, dtype: int64

# %% [markdown]
# ### MiscFeature

# %%
df["MiscFeature"].isna().value_counts()
# Out:
# True     1406
# False      54
# Name: MiscFeature, dtype: int64

# %%
df[df["MiscFeature"].notna()]
df["MiscFeature"].value_counts()
# Out:
# Shed    49
# Gar2     2
# Othr     2
# TenC     1
# Name: MiscFeature, dtype: int64

# %%
df.loc[df["MiscFeature"].isna(), "MiscFeature"] = 0  #0 porque no tienen 
pd.options.display.max_columns = None   #para que muestren todas las columnas
df
# Out:
#         Id MSZoning  LotArea Street Utilities LandSlope HouseStyle  YearBuilt  \
# 0        1       RL     8450   Pave    AllPub       Gtl     2Story       2003
# 1        2       RL     9600   Pave    AllPub       Gtl     1Story       1976
# 2        3       RL    11250   Pave    AllPub       Gtl     2Story       2001
# 3        4       RL     9550   Pave    AllPub       Gtl     2Story       1915
# 4        5       RL    14260   Pave    AllPub       Gtl     2Story       2000
# ...    ...      ...      ...    ...       ...       ...        ...        ...
# 1455  1456       RL     7917   Pave    AllPub       Gtl     2Story       1999
# 1456  1457       RL    13175   Pave    AllPub       Gtl     1Story       1978
# 1457  1458       RL     9042   Pave    AllPub       Gtl     2Story       1941
# 1458  1459       RL     9717   Pave    AllPub       Gtl     1Story       1950
# 1459  1460       RL     9937   Pave    AllPub       Gtl     1Story       1965
#
# ...

# %% [markdown]
# ### Comprove no more nulls

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 35 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotArea        1460 non-null   int64
#  3   Street         1460 non-null   object
#  4   Utilities      1460 non-null   object
#  5   LandSlope      1460 non-null   object
#  6   HouseStyle     1460 non-null   object
#  7   YearBuilt      1460 non-null   int64
#  8   YearRemodAdd   1460 non-null   int64
#  9   RoofStyle      1460 non-null   object
#  10  Foundation     1460 non-null   object
#  11  TotalBsmtSF    1460 non-null   int64
#  12  Heating        1460 non-null   object
#  13  CentralAir     1460 non-null   object
#  14  Electrical     1460 non-null   object
#  15  1stFlrSF       1460 non-null   int64
#  16  2ndFlrSF       1460 non-null   int64
# ...

# %% [markdown]
# ## Describe and save to new csv

# %%
df.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     795.75
# 1stFlrSF       1460.0    1162.626712    386.587738    334.0     882.00
# 2ndFlrSF       1460.0     346.992466    436.528436      0.0       0.00
# GrLivArea      1460.0    1515.463699    525.480383    334.0    1129.50
# BsmtFullBath   1460.0       0.425342      0.518911      0.0       0.00
# FullBath       1460.0       1.565068      0.550916      0.0       1.00
# BedroomAbvGr   1460.0       2.866438      0.815778      0.0       2.00
# KitchenAbvGr   1460.0       1.046575      0.220338      0.0       1.00
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    1460
# dtype: int64

# %%
df.to_csv("data/house_pricing_clean.csv", index=False)
